# %% [markdown]
# #  Selenium 사용하기

# %%
# 셀레니움 라이브러리 설치
# !pip install selenium
# Out:
# Requirement already satisfied: selenium in c:\programdata\anaconda3\lib\site-packages (4.18.1)
# Requirement already satisfied: urllib3[socks]<3,>=1.26 in c:\programdata\anaconda3\lib\site-packages (from selenium) (1.26.16)
# Requirement already satisfied: trio~=0.17 in c:\programdata\anaconda3\lib\site-packages (from selenium) (0.25.0)
# Requirement already satisfied: trio-websocket~=0.9 in c:\programdata\anaconda3\lib\site-packages (from selenium) (0.11.1)
# Requirement already satisfied: certifi>=2021.10.8 in c:\programdata\anaconda3\lib\site-packages (from selenium) (2023.7.22)
# Requirement already satisfied: typing_extensions>=4.9.0 in c:\programdata\anaconda3\lib\site-packages (from selenium) (4.10.0)
# Requirement already satisfied: attrs>=23.2.0 in c:\programdata\anaconda3\lib\site-packages (from trio~=0.17->selenium) (23.2.0)
# Requirement already satisfied: sortedcontainers in c:\programdata\anaconda3\lib\site-packages (from trio~=0.17->selenium) (2.4.0)
# Requirement already satisfied: idna in c:\programdata\anaconda3\lib\site-packages (from trio~=0.17->selenium) (3.4)
# Requirement already satisfied: outcome in c:\programdata\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.3.0.post0)
# Requirement already satisfied: sniffio>=1.3.0 in c:\programdata\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.3.1)
# Requirement already satisfied: cffi>=1.14 in c:\programdata\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.15.1)
# Requirement already satisfied: wsproto>=0.14 in c:\programdata\anaconda3\lib\site-packages (from trio-websocket~=0.9->selenium) (1.2.0)
# Requirement already satisfied: PySocks!=1.5.7,<2.0,>=1.5.6 in c:\programdata\anaconda3\lib\site-packages (from urllib3[socks]<3,>=1.26->selenium) (1.7.1)
# Requirement already satisfied: pycparser in c:\programdata\anaconda3\lib\site-packages (from cffi>=1.14->trio~=0.17->selenium) (2.21)
# Requirement already satisfied: h11<1,>=0.9.0 in c:\programdata\anaconda3\lib\site-packages (from wsproto>=0.14->trio-websocket~=0.9->selenium) (0.14.0)

# %% [markdown]
# # 예제) 대한민국 지역 여행기사 수집
# 예제 페이지 URL https://korean.visitkorea.or.kr/search/search_list.do?keyword=%EC%A0%9C%EC%A3%BC%EB%8F%84

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.options import Options
import math, time

options = Options()
options.add_argument('--window-size=974,1047')
options.add_argument('--window-position=953,0')
options.add_experimental_option("detach", True)

# %%
search = input('검색어를 입력하세요.')
# Out:
# 검색어를 입력하세요.제주도

# %%
URL = 'https://korean.visitkorea.or.kr/search/search_list.do?keyword='+search

driver = webdriver.Chrome(options=options)
driver.get(URL)
time.sleep(3)

# %%
# 여행기사 더보기 클릭
driver.find_element(By.CSS_SELECTOR, "#s_recommend > .more_view > a").click()

# %% [markdown]
# ## 페이지 이동
# ```
# 1 : 수집 갯수를 입력받는다.
# 2 : 수집 갯수에 따라 페이지를 이동한다.
# 3 : 각 페이지별 데이터를 수집한다. (타이틀 텍스트)
# 4 : 출력
# ```

# %%
cnt = int(driver.find_element(By.XPATH, '//*[@id="totalCnt"]').text) # XPath를 통해서 총 건수 찾기
cnt
# Out:
# 284

# %%
page_cnt = math.ceil(cnt / 10) # 크롤링 할 전체 페이지 수 (올림)
print(page_cnt)
# Out:
# 29

# %%
# xpath대신 execute_script함수 사용
# xpath가 안맞는 이슈, 1~5페이지는 괜찮 but 6으로 넘어가면 문제 발생(path 인덱스가 안맞음)
tit_xpath = '//*[@id="search_result"]/ul/li[*]/div[1]/div[1]/a'
no = 0

for x in range(1, page_cnt+1):
    print(f'========= {x} 페이지 작업 =========')
    mylist = driver.find_elements(By.XPATH, tit_xpath)
    
    for item in mylist:
        no += 1
        if no > cnt:
            break
        print(no, item.text)
    
    if no < cnt:
        next_button = driver.find_element(By.CSS_SELECTOR, f"a[id='{x+1}']")
        driver.execute_script("arguments[0].click();", next_button)
        time.sleep(2)
        
print('========= 작업 완료 =========')
driver.close()
# Out:
# ========= 1 페이지 작업 =========
# 1 제주도의 숨겨진 재미를 찾는
# <놀멍, 배우멍 제주마을체험 - 1일형 체험학습>
# 2 제주도가 품은 신비의 화산 숲, 환상숲곶자왈공원
# 3 한국관광공사 추천 2월 걷기여행길, 이른 봄을 맞이하는 제주도 걷기길
# 4 제주도 조천읍 버킷리스트 여행지 작성하기
# 5 [국내 트레킹 추천]
# 제주 올레길 걷기 여행,
# 준비부터 코스 선택까지 꿀팁 총정리!
# 6 김창열의 회귀 철학을 건축으로 표현한 미술관, 제주도립김창열미술관
# 7 제주도 유채꽃 명소 추천, 봄에 떠나는 인생샷 여행
# 8 새하얀 눈으로 덮인 제주도 설경 명소 4
# 9 소소한 '제주여행' 꿀팁! 〈겨울편〉
# 10 사계절 자연의 아름다움을 간직한 제주시 댕댕이 추천코스
# ========= 2 페이지 작업 =========
# 11 제주도 '한정'여행지,
# 제주도의 이색 공간을 찾아서
# 12 연말연시 제주도 여행 추천 코스,
# 가족여행 가볼 만한 곳
# 13 제주의 아크로폴리스를 아시나요? - 제주 원도심 (제주목관아 중심)
# 14 제주 여행, 은빛 물결이 일렁이는 제주도 억새 명소 모음
# 15 마음까지 화사해지는
# 제주도 봄꽃 여행
# 16 제주도 서쪽에서 즐기는 꽉 찬 여행 코스
# 17 제주의 숨겨진 구석구석을 살펴보자, 제주도 박물관 여행
# 18 2월 놓치지 말아야 할 제주 관광 10선
# <2월 제주, 먼저 온 봄기운에 마음 돌랑돌랑>
# 19 맛있는 음식에 여행의 기쁨은 두 배! <제주 식도락 여행>
# 20 반려견과 떠나는 여행 <제주 반려견 숙소&카페>
# ========= 3 페이지 작업 =========
# 21 설렘과 여유가 가득한 제주 여행
# 22 빛으로 물든 '로맨틱 제주' <제주 야간 관광지>
# 23 12월 놓치지 말아야 할 제주 관광 10선
# <올해도 애쓴 당신과 나, 12월의 제주에서 쉬멍쉬멍>
# 24 제주도 서귀포 가볼 만한 곳,
# 초록이 가득한 남쪽 여행 코스
# 25 [팜스테이션] 제주공항과 아름다운 해안이 인접한 워케이션 공간
# 26 안심관광에 알맞은 최고의 야외 공연과 체험 - 제주 더마(馬)파크
# 27 [디어먼데이 제주] 월요병이 없는 세상을 꿈꾸는 이들의 제주 워케이션
# 28 [질그랭이 거점 센터] 조용한 제주 해안마을에서 즐기는 워케이션
# 29 [제주] 푸른 밤의 따뜻한 꿈
# 30 비움과 채움의 조화로 완성한 웰니스 라이프, 제주901
# ========= 4 페이지 작업 =========
# 31 1월 놓치지 말아야 할 제주 관광 10선
# <멋진 새날을 희망하며, 엄블랑한 1월 제주>
# 32 섬 속의 섬 그리고 가장 제주다운 섬, 제주 우도
# 33 제주 해녀들의 “호오이 호오이” 숨비소리 찾는 여행 – 제주해녀박물관과 숨비소리길
# 34 랜선으로 먼저 온 봄 맞이하기!
# 일출로 시작하는 제주도 동쪽 코스
# 35 돌이 나에게 말을 걸어오는 시적(詩的)인 곳– 제주돌문화공원
# 36 [국내여행 버킷리스트 3탄] 올 여름엔 제주도 자전거 여행이다!
# 37 제주의 자연과 제주인의 삶을 최단시간에 알 수 있는 곳! - 제주민속자연사박물관
# 38 식재료 수확체험부터 시작하는 완벽한 쿠킹클래스 - 제주 토토아뜰리에
# 39 환경생태가 살아있는 진짜 제주의 숲을 만나다 – 제주절물자연휴양림과 장생의 숲길
# 40 [제주도 가볼 만한 곳] 섬 안에 섬을 여행하는 방법, 가파도 여행 코스
# ========= 5 페이지 작업 =========
# 41 탄소 없는 섬, 제주의 미래를 만나다_제주CFI에너지미래관
# 42 제주 가볼만한 곳. 가족과 함께 제주도 구석구석, 당일치기 필수 코스 4
# 43 [번아웃 트래블 EP.1] 넉살 발성에 귀가 뚫렸습니다! | 제주도여행
# 44 [김녕 어촌체험휴양마을] 제주 김녕바다를 바라보며 업무를 즐기는 워케이션
# 45 엄마 아빠에겐 쉼표, 아이에겐 느낌표! 아이와 떠나는 제주 여행
# 46 [온실(프립캠프)] 업무와 휴식, 액티비티까지 한 번에 즐기는 제주도 워케이션
# 47 2월 제주 여행, 성산일출봉 근처 인생사진 명소로 유명한 제주 동쪽 핫플레이스 4
# 48 [코사이어티 빌리지] 녹음이 우거진 제주 동쪽 영감의 공간
# 49 가장 먼저 맞이하는 봄날의 하이라이트 '제주 벚꽃 명소'
# 50 나만 알고 싶은 제주 액티비티 ①
# 원시 숲과 벵뒤못과 밀리터리 카,
# 어디에도 없던 리얼 오프로드의 세계
# ========= 6 페이지 작업 =========
# 51 자연 속에서 더욱 단단해지는 가족애, 제주돌문화공원과 교래자연휴양림
# 52 감성 넘치는 인생 사진, 가을 제주 120% 즐기기
# 53 [제주] 연말을 조금 더 특별하게 제주도의 방
# 54 보석 같은 섬에 예술을 덧입히다,
# 제주 추자도
# 55 '효리네 민박'의 색다른 변신!
# 감성 넘치는 제주 로컬 소품샵 소길별하
# 56 '제주 별미 여행' 흑돼지, 말고기에 각재기국과 어랭이물회도 맛보자
# 57 마음에 위안을 주는 제주의 맛
# 58 겨울에 만나는 초록빛 곶자왈, 제주 청수마을
# 59 화산섬 제주의 아름다움을 찾아나선 꿈결 같은 산책, 사려니숲길(제주시험림)
# 60 신비롭고 청정한 자연을 품은 제주 서귀포시 댕댕이 추천코스
# ========= 7 페이지 작업 =========
# 61 제주의 숨은 명소! '진짜 제주'를 만나는 곳, 애월읍 봉성리
# 62 [여행 카드] 제주도에서 만나는 스위스 마을
# 63 2024 여행가는 달(2~3월편) 추천 관광지 [제주]
# 64 길 위의 지질 과학관, 제주도 사계리 지질 여행
# 65 [360도 영상] 제주 항공 편
# 66 제주의 특색을 잘 간직한 안심 산책길, 천지연폭포
# 67 제주 트레킹, 탁 트인 풍경 속을 거니는 제주 걷기 좋은 오름 4
# 68 태곳적 제주와 조우하는 신비로운 숲, 동백동산
# 69 효리네민박 촬영지부터 매화꽃 명소까지,
# ♥제주 봄여행 코스♥
# 70 제주의 즐겁고 달콤한 겨울 박물관들
# ========= 8 페이지 작업 =========
# 71 상큼한 귤밭이 내어준 나만의 치유공간, 제원하늘농원
# 72 세계자연유산(UNESCO)의 봄을 느끼며, 제주도 동부 여행
# 73 [제주] 이동하기 좋은 위치의 숙소를 찾는다면, 제주R호텔
# 74 제주의 자연을 만나다, 서귀포 치유의 숲
# 75 여름, 제주도로 별~난 박물관 피서 떠나봅서예
# 76 제주의 물과 숲을 경험하다, WE호텔 웰니스센터
# 77 '조물조물' 만드는 즐거움 〈DIY 체험 여행지〉
# 78 “바다가 우리에겐 부엌이지.” - 해녀의 부엌_북촌점
# 79 해녀가 되어 바닷속을 누벼볼까!
# 제주 하도어촌체험마을
# 80 바다와 오름을 가르는 거대한 바람개비 '제주 풍력발전단지'
# ========= 9 페이지 작업 =========
# 81 벚꽃과 유채꽃이 서로 뽐내는 제주의 봄날
# 82 가족 단위 추천 느린 여행지 2탄 - 제주시 동부
# 83 1년에 열흘만 열리는 비밀의 원시림, 제주 거문오름 '용암길'
# 84 나 혼자 훌쩍 떠나는 제주도 여행
# 85 <맨도롱 또똣> 어디서 촬영햇수꽈? 제주 풍경 속 달달한 로맨스 스폿을 찾아서
# 86 [국내여행 버킷리스트 1탄] '나도 제주 해녀가 되고 싶어요', 제주 하도어촌체험마을 해녀체험
# 87 알록달록 가을빛 제주
# 88 김만덕을 따라 걷는 제주시 건입동 산책
# 89 가족 단위 추천 느린 여행지 1탄 - 제주시 서부
# 90 제주의 가을은 오름을 타고 온다
# ========= 10 페이지 작업 =========
# 91 늦기 전에 떠나야 할 제주의 숨은 동백 명소 5
# 92 재미 가득한 컴퓨터 세상, 제주 넥슨컴퓨터박물관
# 93 [더가게 함께가게] 제주 매력이 가득! 나만 알고 싶은 특별 굿즈 추천
# 94 은빛 물결 일렁이는 길을 달리다, 제주 억새 드라이브
# 95 찬란한 봄에 떠난 제주4·3 유적지 기행
# 96 여름철 입맛 돋우는 제주 물회 열전
# 97 검은 밤바다, 빛나는 은빛 유혹, 제주 은갈치 대령이오
# 98 어여쁜 동백꽃처럼 내 얼굴도 활짝! 제주동백마을
# 99 여름철 낭만 여행 '제주의 별 헤는 밤'
# 100 인간극장 '엄마의 바다' 그곳을 찾아, 초보 해녀의 꿈이 담긴 제주 평대리 바다
# ========= 11 페이지 작업 =========
# 101 [제주] 푸른 섬 제주와 어울리는 숙소를 만든다는 것, 제주 에코스위츠
# 102 제주 여행, 겨울에 피는 붉은 동백꽃 명소
# 103 Reboot Your Travel in Korea : Jeju-do (제주도)
# 104 비? 오히려 좋아~
# 장마철 제주 여행지 5☔️
# 105 바닷가 시골 장터로 혼저 옵서예! 제주 세화민속오일시장
# 106 다 같이 돌자! 섬 속의 섬, 우도 한 바퀴
# 107 넌 장 보러 가니? 우린 여행 간다! '제주 동문재래시장'
# 108 잠들었던 벙커를 깨운 환상의 빛
# 109 제주 가볼 만한 곳, 동심이 되살아나는 여행 4
# 110 <결혼의 여신>을 따라 떠나는 제주 낭만 여행
# ========= 12 페이지 작업 =========
# 111 제주만의 특별한 힐링을 찾아 - 서귀포 치유의 숲과 열 개의 테마길
# 112 이 여름, 어느 바다로 뛰어들까?! 제주에서 손꼽히는 해수욕장 모음
# 113 우유에서 치즈까지, 홈메이드 치즈 만들기 제주치즈체험하우스
# 114 [사계 어촌체험 휴양마을] 제주 바닷가 마을에서 머물며 일하는 워케이션
# 115 제주섬 끝자락 산에서 바다를 만끽하다 – 송악산
# 116 무공해 '힐링캠프', 가보고 싶지 아니한가! 제주 무병장수테마파크
# 117 셀카 찍기 좋은 제주의 숨은 명소
# 118 제주 유채꽃 명소 추천,
# 가장 먼저 봄을 맞이하는 제주 여행
# 119 화산토로 빚어낸 옹기를 체험하다, 제주 담화헌
# 120 [지질공원 추천] 여기가 제주의 화산학 연구 교과서 제주 수월봉
# ========= 13 페이지 작업 =========
# 121 [고요산책] 사색하는 여행자를 위한, 나만을 위한 고요한 북스테이
# 122 로컬푸드로 만들어 더 맛나다! 제주 별난 빙수 열전
# 123 태초의 제주와 조우하다, 산방산·용머리해안 지질트레일
# 124 제주 여행의 또 다른 매력, 하우스 콘서트 카페
# 125 제주 신화월드 1박2일!
# 제주 서부 맛집도 알려줄게
# 126 [스페이스 모노] 일과 쉼을 동시에 만족하는 맞춤형 제주 워케이션
# 127 멋진 풍경을 품고 있는
# 겨울 제주 여행지 추천
# 128 버려진 건축물에 예술의 옷을 입히다, 제주 아라리오뮤지엄
# 129 [리플로우] 창의적인 사람들을 위한 스테이&코워킹스페이스
# 130 제주 서부 풍광이 한눈에! 제주 서부 새별오름 & 저지오름
# ========= 14 페이지 작업 =========
# 131 봄향기 뿜뿜!
# 제주 사진찍기 좋은 유채꽃밭 4
# 132 확실하게 쉬고! 화끈하게 놀기! 플레이스 캠프 제주
# 133 나만 알고 싶은 제주 액티비티 ②
# 향기 나는 숲에서 커피 한 잔,
# 야생 돌고래 뛰노는 바다에서 쉬영 갑서~
# 134 아빠, 어디가? 제주의 숨은 비경 찾으러! 제주 지미봉 탐험
# 135 제주는 지금 플리마켓 전성시대! 벨롱장, 소랑장, 아라올레 지꺼진장
# 136 봄을 부르는 노란 복수초 꽃길, 제주 한라생태숲
# 137 그윽한 차향에 나를 맡기다, 제주 취다선리조트
# 138 제주 어디까지 가봤니? 알쓸신잡2 북제주편
# 139 바닷가 앞 마법처럼 열리는 장터, 제주 벨롱장 & 세화장
# 140 유채꽃으로 시작하는 봄, 인생사진 찍으러 제주도 가자!
# ========= 15 페이지 작업 =========
# 141 야생화 천국을 가다, 제주 방림원
# 142 [제주] 봄 내음 가득한 제주도민의 봄방학 By 여행작가 슬구
# 143 '맛있는 녀석들' 추천 Must-Eats 20_고기국수
# 144 제주 바다 속에 숨겨진 비경, 행원리 앞 바다 천연 풀장
# 145 제주도 차밭 여행, 차밭에 새순 돋는 소리, 봄이 오는 소리
# 146 [가볼 만한 곳 총집합!] 볼거리, 즐길거리 가득한
# 제주 중문관광단지로 떠나는 여행
# 147 [360도 영상] 제주 여행 편
# 148 '맛있는 녀석들' 추천 Must-Eats 20_성게미역국
# 149 빛의 벙커
# 150 [방구석 제주여행]
# 언제든 떠날 수 있도록, 미리 보고 계획하기!
# ========= 16 페이지 작업 =========
# 151 우도, 성산 그리고 제주올레, 제주 동북부를 가다
# 152 제주의 숨은 별미, 토종닭 요리를 맛보다! 교래마을 토종닭 유통특구
# 153 제주의 바다와 바람을 내 품에, 제주 스쿠터 드라이브
# 154 열린관광지로 향한 가벼운 발걸음, 제주 서귀포
# 155 '맛있는 녀석들' 추천 Must-Eats 20_흑돼지근고기
# 156 화산이 빚어낸 겹겹이 쌓인 시간 속을 걷다.
# 157 수련꽃 만발한 연못과 천연림 나들이, 제주 선흘반못과 동백동산 숲길
# 158 겨울 제주로 감귤 따러 가요
# 159 새벽 5시부터 오후 3시까지! 제주 해장국 타임
# 160 '신비의 섬' 우도의 신상 여행지! 자연•문화•미식의 완전체, 훈데르트바서파크
# ========= 17 페이지 작업 =========
# 161 오동통통! 고사리 한 바구니 꺾어가세요~ '제주 고사리'
# 162 [제주] 달콤한 감귤 같은 숙소, 제주 에코 스위츠
# 163 가드닝센터, 카페, 오름, 신화... 없는 게 없는 제주 여행 종합선물세트 '소원 비는 마을' 송당리
# 164 제주 육,해,공 레포츠
# 165 호젓하게 즐기는 제주의 숨은 억새 명소
# 166 보기 좋은 떡이 먹기도 좋다 HOT한 제주 먹거리
# 167 차와 명상에 오롯이 취하는 시간, 취다선 리조트
# 168 삶의 휴식을 원하는 내 몸과 마음의 오아시스, 비젠빌리지(Wiesen Village)
# 169 제주를 품은 공간, 예술에 스민 제주
# 170 제주, 화려함 뒤에 감춰진 비운의 역사를 재조명하다!
# ========= 18 페이지 작업 =========
# 171 누구나 편하게 걷는 아름다운 숲길
# 172 아바타도 반한 신비의 숲, 제주 환상숲 곶자왈공원
# 173 청보리 물결 일렁이는, 그 섬에 가고 싶다 '제주 가파도'
# 174 춥다고? 올레로 나와 바! 간세다리 제주걷기
# 175 제주에서 즐기는 육, 해, 공 레포츠 3종 세트! 저브&빅볼, 투명카약, 패러세일링
# 176 항구ㆍ바다ㆍ오름 그리고 중산간, 제주 남서부를 가다
# 177 봄꽃이 가득한 제주 나들이
# 178 2021 생활관광 공모전 포토에세이 장려상 - 유수진
# 179 또 다른 즐거움, 맛있는 제주 여행! 제주 서부 맛집을 찾아
# 180 '건축학개론' 속 서연의 집을 찾아 '제주 위미리 & 올레 5코스'
# ========= 19 페이지 작업 =========
# 181 용암이 빚은 동굴들의 시작점,거문오름
# 182 왕(와서), 봥(보고), 강 (가서) 또시 오고푼 (다시 오고 싶은) 오래된 정원 - 일출랜드
# 183 2021 생활관광 공모전 포토에세이 우수상 - 최수나
# 184 박물관, 어디까지 가봤니? 여름휴가맞이 제주 박물관 총정리
# 185 제주안의 새로움을 찾는 여행,
# 중문의 재발견
# 186 [여행 카드]모든 맛이 좋았다!군침 부르는 제주 향토음식
# 187 이곳에선 나도 드라마 주인공! 제주 로케디오 월드
# 188 제주 가볼만한 곳. 싱그러운 제주의 봄! 가볍고 완벽한 제주 여행 코스
# 189 제주를 담다, 제주를 닮다 지오푸드
# 190 입안 가득 군침 도는 제주 주전부리 여행
# ========= 20 페이지 작업 =========
# 191 세계적인 명소에서 맞는 신년 해맞이, 제주 성산일출축제
# 192 들어는 봤수꽈? 먹어는 봤수꽈? 명품 우리 소, 제주 흑한우
# 193 '신들의 만찬'보다 더 푸짐한 한 상 '한여름날의 우도'
# 194 미끄럼 타는 흑돼지 보고 동백축제도 즐기는 제주 휴애리자연생활공원
# 195 [8월 걷기여행길10선] 서귀포 칠십리에서 문화를 만나다, 제주 서귀포시 작가의 산책길-유토피아로
# 196 배신당한 여행자를 위로하는 제주의 겨울 맛집, 멋집
# 197 섬을 할퀴고 간 깊은 상처 '영화 <지슬>, 제주 4.3을 말하다'
# 198 '이어도 사나, 어이~ 어이~' 제주 해녀 물질 체험
# 199 제주 해녀축제 & 혼인지축제
# 200 선계로 통하는 문 '제주 방선문계곡'
# ========= 21 페이지 작업 =========
# 201 바닷가 앞 꽃을 피우다, 김녕금속공예벽화마을 고장난길
# 202 서지현 님의 우리 가족을 위한 유쾌한 여행 (맞춤형 힐링여행 프로젝트)
# 203 치유의 숲으로 초대합니다, 한라산 둘레길
# 204 [제주] 제주 정원 곁에서 온전하게 휴식하고 싶다면, 꿈꾸는 노마드
# 205 어둠의 벙커에서 빛과 음악의 궁전으로, 서귀포 빛의벙커
# 206 파랗게 파랗게 물들었네~ 여름 제주 엿보기!
# 207 나를 설레게 하는 제주 추자도 여행코스
# 208 2021 생활관광 공모전 포토에세이 장려상 - 조아현
# 209 수국이 수국수국 제주 수국 스팟 모음
# 210 아시아 최대규모 제주항공우주박물관
# ========= 22 페이지 작업 =========
# 211 화산섬이 빚은 천연 바다 풀장, 제주 황우지해안
# 212 2021 생활관광 공모전 포토에세이 대상 - 신유경
# 213 [제주] 아이와 행복한 추억을 쌓을 계획이라면, 더 세리 리조트
# 214 [여행 카드] 여심 확실히 잡는 5월 BEST 여행지는?
# 215 [제주 오름 추천] 진짜 제주를 만나다. 제주 오름 여행 코스
# 216 오지게 멋진 제주 건축물 여행
# 217 한국관광공사 추천! 9월 가볼 만한 곳 '세계유산 즐기기 2편'
# 218 자연이 기른 재료로 정성껏 지은 밥상, 제주 템플스테이푸드
# 219 [O-Peace 사계점] 일과 쉼, 모두 평화롭게
# 220 [O-Peace 조천점] 새로운 방식으로 일하는 사람들을 위한 창조적 오피스
# ========= 23 페이지 작업 =========
# 221 혼자여도 따뜻한 제주
# 222 12월 제주 핫플 제주 동백꽃 스팟
# 223 바다 완전정복 우도
# 224 대한민국 걷기 열풍의 주역
# 225 새콤달콤 제주
# 226 2021 생활관광 공모전 포토에세이 우수상 - 정유리, 최은교
# 227 광치기해변에서 바라보는 성산일출봉의 일출
# 228 '비 온 후 폭포'를 아시나요? 제주 엉또폭포와 천제연 제1폭포
# 229 가베또롱하고 엄부랑한 힐링 숲길,
# 서귀포치유의숲
# 230 전기장판에서 벗어나자 제주 감귤 체험
# ========= 24 페이지 작업 =========
# 231 제주 핫플레이스 모음 제주에서 놀멍쉬멍
# 232 자연과 호흡하며 즐기는 사격?ATV 체험장, 제주 대유랜드
# 233 제주산 커피, 드셔보셨나요? 제주 코리아커피농장
# 234 꽃, 바다, 숲 모든 것이 다 있는 완전체 제주 여행
# 235 예신, 예랑이를 위한 제주 웨딩촬영 스팟
# 236 화가 이중섭과 남국의 바다, 제주 서귀포
# 237 예쁘고 아기자기한 것이 좋아! 여자들이 좋아하는 제주 여행
# 238 제주 서귀포
# 239 제주절물자연휴양림
# 240 개구쟁이 두 소년의 '올 댓 초콜릿' 제주 초콜릿랜드
# ========= 25 페이지 작업 =========
# 241 하늘 정원을 거닐고 깊은 숲 생명수를 찾아 나서다, 1100고지 습지&동백동산 습지
# 242 제주 지오(Geo)브랜드 : 유네스코 세계지질공원 활용 지질관광
# 243 핑덕들 마음이 두근두근 핑크핑크한 제주 여행지
# 244 2021 생활관광 공모전 포토에세이 최우수상 - 조은비
# 245 집념과 인연, 사색이 공존하는 제주 추사유배길을 걷다
# 246 요리보고 조리보고 '표선면편'
# <사계절 방문하기 좋은 포근한 곳>
# 247 <에디터픽> 컬러풀한 제주의 봄으로! 떠나요 제주도~
# 248 봄을 미리 만나는 제주 매화 축제 모음.zip
# 249 순이와 철수의 애틋한 러브 스토리 '늑대소년' 촬영지를 찾아서
# 250 행원도 앞바다 그리고 쇠소깍
# ========= 26 페이지 작업 =========
# 251 걷고 보고, 먹는 즐거움이 넘치는
# 252 럭셔리 캠핑의 대명사 '글램핑을 아시나요?'
# 253 최남단 막내 섬에서 새해의 기운을 받다, 마라도 일출
# 254 제주 말이 궁금해? 궁금하면 여기! 제주 조랑말체험공원
# 255 2021 생활관광 공모전 영상콘텐츠부문 우수상 – 박균성
# 256 사진 찍기 좋은 곳 '제주 사진 명소'
# 257 2021 생활관광 공모전 영상콘텐츠부문 우수상 – 김원지, 양지환
# 258 육지 위에 제주도, 돌담길이 매력적인
# '남천고택'
# 259 제주 주전부리 여행
# 260 서귀포 매일올레시장
# ========= 27 페이지 작업 =========
# 261 2021 생활관광 공모전 영상콘텐츠부문 장려상 – 정유리, 최은교
# 262 2021 생활관광 공모전 영상콘텐츠부문 장려상 – 강초록
# 263 2021 생활관광 공모전 영상콘텐츠부문 우수상 – 이현숙
# 264 제주 모슬포 방어회 식도락 여행
# 265 제주의 삶과 문화를 느낄 수 있는 어멍아방잔치마을 여행 코스
# 266 금속공예가 꽃핀 마을 '김녕금속공예벽화마을'
# 267 [국내여행 버킷리스트 2탄] 나도 한다 마라도 짜장 투어!
# 268 다희연 짚라인 체험. 나, 지금 날고 있니?
# 269 캠핑을 원하는 이들이여, 부담 없이 오라! '제주 중문진실캠핑장'
# 270 박물관 완전정복 알쓸신잡2 남제주편
# ========= 28 페이지 작업 =========
# 271 [여행 카드] 봄, 천천히 걸으면 더 많이 보여요 ♪, Miss Flower-스탠딩에그
# 272 마라도 짜장면 투어
# 273 남다른 과거를 가진 전국 이색카페
# 274 삼겹살데이맞이 에블바디 돼지파티
# 275 [여행 카드] 그와 그녀를 위한 셀프 웨딩스냅 촬영 명소
# 276 반짝반짝 프사 완성 네온사인 카페
# 277 미리 떠나는 여름휴가 해양 스포츠
# 278 과거를 여행하는 커플스냅
# 279 한번 뿐인 인생 무조건 해봐야 할 LIST 4
# 280 남모를 기억 간직한 전국 공간재생 카페
# ========= 29 페이지 작업 =========
# 281 [행정안전부 x 한국섬진흥원] 2023 찾아가고 싶은 가을섬 5 : 강화 교동도, 안산 대부도, 제주 추자도, 여수 금오도, 남해 조도 · 호도
# 282 겨울의 끝자락에서 봄꽃을 미리봄
# 283 가을은 코스모스만? 형형색색 품은 가을 모음
# 284 [여행 카드] 명절증후군이시군요? 당신께 풀빌라를 처방합니다! 럭셔리하고 저렴한 남해&제주 풀빌라5
# ========= 작업 완료 =========
